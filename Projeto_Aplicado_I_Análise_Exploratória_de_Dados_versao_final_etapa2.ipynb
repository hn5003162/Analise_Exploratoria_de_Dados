# %% [markdown]
# <a href="https://colab.research.google.com/github/hn5003162/Analise_Exploratoria_de_Dados/blob/main/Projeto_Aplicado_I_An%C3%A1lise_Explorat%C3%B3ria_de_Dados_versao_final_etapa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Leitura do dataframe. O parâmetro decimal = "," informa que a "," deve ser considerado como separador de decimais. sep = "|" indica qual é o separados dos campos.
base = pd.read_csv("https://raw.githubusercontent.com/hn5003162/Mack_Projeto_Aplicado_I/main/base-projeto-aplicado-i.csv",sep="|",decimal = ",")

# Exploração inicial dos dados. Primeiros registros:
base.head()
# Out:
#     ano sigla_uf   nome_uf nome_regiao produto  area_plantada  area_colhida  \
# 0  2010       AC      Acre       Norte    Café         1271.0        1003.0
# 1  2010       AL   Alagoas    Nordeste    Café            5.0           5.0
# 2  2010       AM  Amazonas       Norte    Café         2432.0        2048.0
# 3  2010       AP     Amapá       Norte    Café            NaN           NaN
# 4  2010       BA     Bahia    Nordeste    Café       152056.0      152056.0
#
#    quantidade_produzida   perdas  valor_producao  ...  area_cafe  \
# 0                1029.0  279.847          2777.0  ...        NaN
# 1                   2.0    0.000             1.0  ...        NaN
# 2                3902.0  758.988          8804.0  ...        NaN
# 3                   NaN      NaN             NaN  ...        NaN
# 4              153262.0    0.000        560050.0  ...        NaN
#
#    producao_cafe  valor_total_producao_cafe  despesa_total_comparacao  \
# 0            NaN                        NaN                       NaN
# 1            NaN                        NaN                       NaN
# 2            NaN                        NaN                       NaN
# 3            NaN                        NaN                       NaN
# 4            NaN                        NaN                       NaN
#
#    despesa_total  despesa_defensivos  quantidade_tratores  \
# 0            NaN                 NaN                  NaN
# 1            NaN                 NaN                  NaN
# 2            NaN                 NaN                  NaN
# 3            NaN                 NaN                  NaN
# 4            NaN                 NaN                  NaN
#
#    quantidade_maquina_colheita  quantidade_maquinas_plantio  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    proporcao_despesa_defensivos
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 23 columns]

# %%
# Dados sobre o dataset: número de linhas e de colunas
base.shape
# Out:
# (216, 23)

# %%
# Estrutura do dataset
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ano                               216 non-null    int64
#  1   sigla_uf                          216 non-null    object
#  2   nome_uf                           216 non-null    object
#  3   nome_regiao                       216 non-null    object
#  4   produto                           216 non-null    object
#  5   area_plantada                     129 non-null    float64
#  6   area_colhida                      129 non-null    float64
#  7   quantidade_produzida              129 non-null    float64
#  8   perdas                            129 non-null    float64
#  9   valor_producao                    129 non-null    float64
#  10  emissao                           216 non-null    float64
#  11  area_nao_utilizada                27 non-null     float64
#  12  quantidade_estabelecimentos_cafe  27 non-null     float64
#  13  area_cafe                         27 non-null     float64
#  14  producao_cafe                     27 non-null     float64
#  15  valor_total_producao_cafe         27 non-null     float64
#  16  despesa_total_comparacao          27 non-null     float64
#  17  despesa_total                     27 non-null     float64
#  18  despesa_defensivos                27 non-null     float64
#  19  quantidade_tratores               27 non-null     float64
#  20  quantidade_maquina_colheita       27 non-null     float64
#  21  quantidade_maquinas_plantio       27 non-null     float64
#  22  proporcao_despesa_defensivos      27 non-null     float64
# dtypes: float64(18), int64(1), object(4)
# memory usage: 38.9+ KB

# %%
# Valores das colunas
base.describe(include='all')
# Out:
#                ano sigla_uf nome_uf nome_regiao produto  area_plantada  \
# count    216.00000      216     216         216     216   1.290000e+02
# unique         NaN       27      27           5       1            NaN
# top            NaN       AC    Acre    Nordeste    Café            NaN
# freq           NaN        8       8          72     216            NaN
# mean    2013.50000      NaN     NaN         NaN     NaN   1.265915e+05
# std        2.29661      NaN     NaN         NaN     NaN   2.563047e+05
# min     2010.00000      NaN     NaN         NaN     NaN   5.000000e+00
# 25%     2011.75000      NaN     NaN         NaN     NaN   1.648000e+03
# 50%     2013.50000      NaN     NaN         NaN     NaN   1.120100e+04
# 75%     2015.25000      NaN     NaN         NaN     NaN   1.520560e+05
# max     2017.00000      NaN     NaN         NaN     NaN   1.041541e+06
#
#         area_colhida  quantidade_produzida       perdas  valor_producao  ...  \
# count   1.290000e+02          1.290000e+02   129.000000    1.290000e+02  ...
# unique           NaN                   NaN          NaN             NaN  ...
# top              NaN                   NaN          NaN             NaN  ...
# freq             NaN                   NaN          NaN             NaN  ...
# mean    1.262692e+05          1.765149e+05   328.541264    9.987940e+05  ...
# std     2.561992e+05          3.834141e+05  1159.013713    2.433704e+06  ...
# min     5.000000e+00          2.000000e+00     0.000000    1.000000e+00  ...
# 25%     1.538000e+03          1.534000e+03     0.000000    6.687000e+03  ...
# 50%     1.120100e+04          1.218200e+04     0.399000    4.017100e+04  ...
# 75%     1.520560e+05          1.408360e+05    81.667000    6.946090e+05  ...
# max     1.041540e+06          1.834171e+06  7307.301000    1.402012e+07  ...
#
#             area_cafe  producao_cafe  valor_total_producao_cafe  \
# count       27.000000   2.700000e+01               2.700000e+01
# unique            NaN            NaN                        NaN
# top               NaN            NaN                        NaN
# freq              NaN            NaN                        NaN
# mean     46251.148148   6.761174e+04               5.320704e+05
# std     174508.631602   2.661681e+05               1.968547e+06
# min          0.000000   0.000000e+00               0.000000e+00
# 25%          0.000000   0.000000e+00               2.835000e+03
# 50%        144.000000   6.500000e+01               1.702600e+04
# 75%       2758.500000   3.766000e+03               1.520090e+05
# max     903032.000000   1.380573e+06               1.024950e+07
#
#         despesa_total_comparacao  despesa_total  despesa_defensivos  \
# count               2.700000e+01   2.700000e+01           27.000000
# unique                       NaN            NaN                 NaN
# top                          NaN            NaN                 NaN
# freq                         NaN            NaN                 NaN
# mean                1.190120e+06   1.701248e+06       151573.481481
# std                 1.750389e+06   2.354958e+06       155577.287171
# min                 4.971000e+03   5.438300e+04         3206.000000
# 25%                 4.696500e+04   4.743115e+05        50729.500000
# 50%                 2.878030e+05   6.798150e+05       100601.000000
# 75%                 1.990214e+06   2.140766e+06       200419.000000
# max                 6.268032e+06   1.097884e+07       673111.000000
#
#         quantidade_tratores  quantidade_maquina_colheita  \
# count          2.700000e+01                 2.700000e+01
# unique                  NaN                          NaN
# top                     NaN                          NaN
# freq                    NaN                          NaN
# mean           1.702416e+07                 5.828436e+06
# std            2.089218e+07                 6.276819e+06
# min            3.527460e+05                 9.003300e+04
# 25%            2.371060e+06                 1.164270e+06
# 50%            6.544964e+06                 2.830683e+06
# 75%            2.395181e+07                 9.269072e+06
# max            5.971232e+07                 2.344271e+07
#
#         quantidade_maquinas_plantio  proporcao_despesa_defensivos
# count                  2.700000e+01                     27.000000
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                   4.075691e+06                      0.136222
# std                    4.672099e+06                      0.084676
# min                    6.421900e+04                      0.036000
# 25%                    6.891330e+05                      0.065000
# 50%                    1.296181e+06                      0.109000
# 75%                    6.730812e+06                      0.191500
# max                    1.824127e+07                      0.312000
#
# [11 rows x 23 columns]

# %%
# Qual é a relação entre a área plantada e a emissão de gases de efeito estufa?
# Qual é a relação entre a quantidade produzida e a emissão de gases de efeito estufa?
# Qual é a relação entre a produtividade (quantidade_produzida / area_plantada) e a emissão de gases de efeito estufa?

# Cria o dataframe e retira todo e qualquer registro com NaN, seja da area plantada, da quantidade produzida ou na emissao"
base_emissao_por_area_ou_qtd = base[["nome_regiao","area_plantada","quantidade_produzida","emissao"]]

base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.dropna()

# Agrupa os dados por região e soma as áreas plantadas, quantidades produzidas e as emissões
base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.groupby(["nome_regiao"])
base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.sum()

# adiciona uma coluna da produtividade (quantidade_produzida / area_plantada)
base_emissao_por_area_ou_qtd["produtividade"] = base_emissao_por_area_ou_qtd["quantidade_produzida"] / base_emissao_por_area_ou_qtd["area_plantada"]

# adiciona uma coluna com a relação entre as emissões e a área plantada.
base_emissao_por_area_ou_qtd["emissao_por_area_plantada"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["area_plantada"]
# adiciona uma coluna com a relação entre as emissões e a quantidade produzida
base_emissao_por_area_ou_qtd["emissao_por_qtd_produzida"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["quantidade_produzida"]

# adiciona uma coluna com a relação entre as emissões e a produtividade
base_emissao_por_area_ou_qtd["emissao_por_produtividade"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["produtividade"]


display(base_emissao_por_area_ou_qtd)
# Out:
#               area_plantada  quantidade_produzida      emissao  produtividade  \
# nome_regiao
# Centro-oeste       221474.0              229522.0  1767311.367       1.036338
# Nordeste          1318472.0             1334635.0  1250093.182       1.012259
# Norte              924910.0              857190.0    16515.290       0.926782
# Sudeste          13403920.0            19647970.0   883600.881       1.465838
# Sul                461527.0              701108.0  1375359.190       1.519105
#
#               emissao_por_area_plantada  emissao_por_qtd_produzida  \
# nome_regiao
# Centro-oeste                   7.979769                   7.699965
# Nordeste                       0.948138                   0.936655
# Norte                          0.017856                   0.019267
# Sudeste                        0.065921                   0.044972
# Sul                            2.980019                   1.961694
#
#               emissao_por_produtividade
# nome_regiao
# Centro-oeste               1.705342e+06
# Nordeste                   1.234954e+06
# Norte                      1.782004e+04
# Sudeste                    6.027959e+05
# Sul                        9.053746e+05

# %%
# Quais sãs as perda de cada região?

# Cria um dataframe, eliminando registro que contenha NaN em perdas ou area plantada
base_perda_por_regiao = base[["nome_regiao","perdas","area_plantada"]]
base_perda_por_regiao.dropna()

# Agrupa os dados por ano e região e soma as perdas e areas plantadas
base_perda_por_regiao = base_perda_por_regiao.groupby(['nome_regiao'])
base_perda_por_regiao = base_perda_por_regiao.sum()


base_perda_por_regiao["perda_por_area_plantada"] = base_perda_por_regiao["perdas"] / base_perda_por_regiao["area_plantada"]


# Exibe o dataframe como uma tabela
display(base_perda_por_regiao)
# Out:
#                  perdas  area_plantada  perda_por_area_plantada
# nome_regiao
# Centro-oeste    582.188       221474.0                 0.002629
# Nordeste      11285.072      1318472.0                 0.008559
# Norte         14665.339       924910.0                 0.015856
# Sudeste       12620.574     13403920.0                 0.000942
# Sul            3228.650       461527.0                 0.006996

# %% [markdown]
# A PARTIR DAQUI É HISTÓRICO ANTIGO

# %%
# Agrupado por região e ano

base_perda_regiao = base[["ano","nome_regiao","perdas"]]
base_perda_regiao.dropna()

base_perda_regiao = base_perda_regiao.groupby(['nome_regiao','ano'])
base_perda_regiao = base_perda_regiao.sum()

display(base_perda_regiao)

#Perdas totais por ano
base_perda_regiao = base[["ano","nome_regiao","perdas"]]
base_perda_regiao.dropna()

base_perda_regiao = base_perda_regiao.groupby(['ano'])
base_perda_regiao = base_perda_regiao.sum()

display(base_perda_regiao)
# Out:
#                      perdas
# nome_regiao  ano
# Centro-oeste 2010    73.000
#              2011     0.282
#              2012     0.274
#              2013    35.055
#              2014     5.466
#              2015   321.130
#              2016   146.357
#              2017     0.624
# Nordeste     2010     0.000
#              2011     0.226
#              2012   163.723
#              2013    32.727
#              2014  1062.496
#              2015  7121.073
#              2016   842.320
#              2017  2062.507
# Norte        2010  1038.835
#              2011   286.348
#              2012   510.815
#              2013  4797.614
#              2014   229.711
#              2015   225.188
#              2016  7336.020
#              2017   240.808
# Sudeste      2010  1109.897
#              2011     3.423
#              2012  1010.505
#              2013   791.382
#              2014   598.136
#              2015  7222.347
#              2016  1590.948
#              2017   293.936
# Sul          2010     0.000
#              2011     1.672
#              2012  1212.627
#              2013   110.429
#              2014  1460.454
#              2015   309.733
#              2016    76.683
#              2017    57.052
# <ipython-input-94-bcc8bd087c3f>:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   base_perda_regiao = base_perda_regiao.sum()
#          perdas
# ano
# 2010   2221.732
# 2011    291.951
# 2012   2897.944
# 2013   5767.207
# 2014   3356.263
# 2015  15199.471
# 2016   9992.328
# 2017   2654.927

# %%
# Qual é a relação de perdas e emissão?

# 1) Qual é a relação entre o plantio e a emissão de gases de efeito estufa?
base_perdas_emissao = base[["nome_regiao","ano","area_plantada","area_colhida","perdas","emissao"]]
#Retira todo e qualquer registro com NA, seja da area plantada ou na emissao"
base_perdas_emissao.dropna()

base_perdas_emissao = base_perdas_emissao.groupby(['nome_regiao','ano'])
base_perdas_emissao = base_perdas_emissao.sum()


base_perdas_emissao["perda_area_plantada"] = base_perdas_emissao["perdas"] /  base_perdas_emissao["area_plantada"]
base_perdas_emissao["area_colhida_plantada"] = base_perdas_emissao["area_colhida"] /  base_perdas_emissao["area_plantada"]


display(base_perdas_emissao)
# Out:
#                    area_plantada  area_colhida    perdas      emissao  \
# nome_regiao  ano
# Centro-oeste 2010        27465.0       27400.0    73.000   190981.313
#              2011        30841.0       30841.0     0.282   237783.155
#              2012        31517.0       31517.0     0.274   245794.916
#              2013        28790.0       28770.0    35.055   209243.539
#              2014        27386.0       27386.0     5.466   228969.004
#              2015        28812.0       28651.0   321.130   219638.838
#              2016        24259.0       24179.0   146.357   207676.099
#              2017        22404.0       22401.0     0.624   227224.503
# Nordeste     2010       163366.0      163366.0     0.000   287474.726
#              2011       166370.0      166370.0     0.226   311106.299
#              2012       169260.0      168884.0   163.723   296987.037
#              2013       170690.0      170628.0    32.727   286390.545
#              2014       170957.0      169829.0  1062.496   297580.760
#              2015       173955.0      170524.0  7121.073   299908.499
#              2016       172040.0      170236.0   842.320   287599.747
#              2017       131834.0      128935.0  2062.507   289680.303
# Norte        2010       171510.0      170858.0  1038.835    14283.199
#              2011       167140.0      166916.0   286.348    14154.001
#              2012       138064.0      137554.0   510.815    14999.851
#              2013       107926.0      100043.0  4797.614    15359.413
#              2014        92310.0       92009.0   229.711    15284.309
#              2015        84056.0       83791.0   225.188    15367.939
#              2016        89774.0       81631.0  7336.020    15149.345
#              2017        74130.0       73971.0   240.808    15057.627
# Sudeste      2010      1716810.0     1715488.0  1109.897    94255.340
#              2011      1709794.0     1709794.0     3.423   101137.576
#              2012      1711332.0     1710549.0  1010.505   103940.732
#              2013      1721887.0     1721222.0   791.382   106242.297
#              2014      1673165.0     1672778.0   598.136   112129.905
#              2015      1654702.0     1650197.0  7222.347   119766.073
#              2016      1679099.0     1677232.0  1590.948   122167.574
#              2017      1537131.0     1536983.0   293.936   123961.384
# Sul          2010        82673.0       82673.0     0.000  1064857.451
#              2011        74854.0       74854.0     1.672  1063188.210
#              2012        72400.0       71576.0  1212.627  1045301.824
#              2013        64964.0       64859.0   110.429  1072395.094
#              2014        38333.0       35825.0  1460.454  1077459.496
#              2015        44747.0       44551.0   309.733  1066430.963
#              2016        43388.0       43326.0    76.683  1097022.100
#              2017        40168.0       40127.0    57.052  1058251.658
#
#                    perda_area_plantada  area_colhida_plantada
# nome_regiao  ano
# Centro-oeste 2010             0.002658               0.997633
#              2011             0.000009               1.000000
#              2012             0.000009               1.000000
#              2013             0.001218               0.999305
#              2014             0.000200               1.000000
#              2015             0.011146               0.994412
#              2016             0.006033               0.996702
#              2017             0.000028               0.999866
# Nordeste     2010             0.000000               1.000000
#              2011             0.000001               1.000000
#              2012             0.000967               0.997779
#              2013             0.000192               0.999637
#              2014             0.006215               0.993402
#              2015             0.040936               0.980277
#              2016             0.004896               0.989514
#              2017             0.015645               0.978010
# Norte        2010             0.006057               0.996198
#              2011             0.001713               0.998660
#              2012             0.003700               0.996306
#              2013             0.044453               0.926959
#              2014             0.002488               0.996739
#              2015             0.002679               0.996847
#              2016             0.081717               0.909294
#              2017             0.003248               0.997855
# Sudeste      2010             0.000646               0.999230
#              2011             0.000002               1.000000
#              2012             0.000590               0.999542
#              2013             0.000460               0.999614
#              2014             0.000357               0.999769
#              2015             0.004365               0.997277
#              2016             0.000948               0.998888
#              2017             0.000191               0.999904
# Sul          2010             0.000000               1.000000
#              2011             0.000022               1.000000
#              2012             0.016749               0.988619
#              2013             0.001700               0.998384
#              2014             0.038099               0.934573
#              2015             0.006922               0.995620
#              2016             0.001767               0.998571
#              2017             0.001420               0.998979

# %%
# Agrupar dados por região
base_por_regiao = base.groupby(['nome_regiao','ano'])
base_por_regiao = base_por_regiao.sum()
base_por_regiao[["area_colhida","emissao"]]
# Out:
# <ipython-input-135-61ee79ca2042>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   base_por_regiao = base_por_regiao.sum()
#                    area_colhida      emissao
# nome_regiao  ano
# Centro-oeste 2010       27400.0   190981.313
#              2011       30841.0   237783.155
#              2012       31517.0   245794.916
#              2013       28770.0   209243.539
#              2014       27386.0   228969.004
#              2015       28651.0   219638.838
#              2016       24179.0   207676.099
#              2017       22401.0   227224.503
# Nordeste     2010      163366.0   287474.726
#              2011      166370.0   311106.299
#              2012      168884.0   296987.037
#              2013      170628.0   286390.545
#              2014      169829.0   297580.760
#              2015      170524.0   299908.499
#              2016      170236.0   287599.747
#              2017      128935.0   289680.303
# Norte        2010      170858.0    14283.199
#              2011      166916.0    14154.001
#              2012      137554.0    14999.851
#              2013      100043.0    15359.413
#              2014       92009.0    15284.309
#              2015       83791.0    15367.939
#              2016       81631.0    15149.345
#              2017       73971.0    15057.627
# Sudeste      2010     1715488.0    94255.340
#              2011     1709794.0   101137.576
#              2012     1710549.0   103940.732
#              2013     1721222.0   106242.297
#              2014     1672778.0   112129.905
#              2015     1650197.0   119766.073
#              2016     1677232.0   122167.574
#              2017     1536983.0   123961.384
# Sul          2010       82673.0  1064857.451
#              2011       74854.0  1063188.210
#              2012       71576.0  1045301.824
#              2013       64859.0  1072395.094
#              2014       35825.0  1077459.496
#              2015       44551.0  1066430.963
#              2016       43326.0  1097022.100
#              2017       40127.0  1058251.658

# %%
# Perda de alimentos por região:
# mudar forma de cálculo usando groupby() // 22/09/2023 Hideki

#Cria um datafame somente das perdar por região. Elimina as regiões que não tem dados (NA)
base_perda = base[["nome_regiao","area_plantada","perdas"]]
# Elimina todos os registro que tenham NA no campo perdas
base_perda = base_perda.dropna(subset=['perdas'])

#Area plantada em números absolutos de 2010 a 2017"
print()
print("Area plantada: números absolutos")
print("Norte        : ",base_perda[base_perda.nome_regiao == "Norte"].area_plantada.sum())
print("Nordeste     : ",base_perda[base_perda.nome_regiao == "Nordeste"].area_plantada.sum())
print("Centro-oeste : ",base_perda[base_perda.nome_regiao == "Centro-oeste"].area_plantada.sum())
print("Sudeste      : ",base_perda[base_perda.nome_regiao == "Sudeste"].area_plantada.sum())
print("Sul          : ",base_perda[base_perda.nome_regiao == "Sul"].area_plantada.sum())


#Perdas em números absolutos:
print()
print("Perdas de 2010 a 2017:")
print("Norte       :",base_perda[base_perda.nome_regiao == "Norte"].perdas.sum())
print("Nordeste    :",base_perda[base_perda.nome_regiao == "Nordeste"].perdas.sum())
print("Centro-oeste:",base_perda[base_perda.nome_regiao == "Centro-oeste"].perdas.sum())
print("Sudeste     :",base_perda[base_perda.nome_regiao == "Sudeste"].perdas.sum())
print("Sul         :",base_perda[base_perda.nome_regiao == "Sul"].perdas.sum())

#Perdas proporcionais à area plantada
print()
print("Perdas proporcionais à area plantada de 2010 a 2017:")
print("Norte       : ","{0:.5f}".format(base_perda[base_perda.nome_regiao == "Norte"].perdas.sum() / base_perda[base_perda.nome_regiao == "Norte"].area_plantada.sum()))
print("Nordeste    : ","{0:.5f}".format(base_perda[base_perda.nome_regiao == "Nordeste"].perdas.sum() / base_perda[base_perda.nome_regiao == "Nordeste"].area_plantada.sum()))
print("Centro-oeste: ","{0:.5f}".format(base_perda[base_perda.nome_regiao == "Centro-oeste"].perdas.sum() / base_perda[base_perda.nome_regiao == "Centro-oeste"].area_plantada.sum()))
print("Sudeste     : ","{0:.5f}".format(base_perda[base_perda.nome_regiao == "Sudeste"].perdas.sum() / base_perda[base_perda.nome_regiao == "Sudeste"].area_plantada.sum()))
print("Sul         : ","{0:.5f}".format(base_perda[base_perda.nome_regiao == "Sul"].perdas.sum() / base_perda[base_perda.nome_regiao == "Sul"].area_plantada.sum()))
# Out:
# Area plantada:
# Norte       :  924910.0
# Nordeste    :  1318472.0
# Centro-oeste:  221474.0
# Sudeste     :  13403920.0
# Sul         :  461527.0
#
# Perdas de 2010 a 2017:
# Norte       : 14665.339
# Nordeste    : 11285.072
# Centro-oeste: 582.188
# Sudeste     : 12620.574
# Sul         : 3228.65
#
# Perdas proporcionais à area plantada de 2010 a 2017:
# Norte       :  0.01586
# Nordeste    :  0.00856
# Centro-oeste:  0.00263
# Sudeste     :  0.00094
# Sul         :  0.00700
