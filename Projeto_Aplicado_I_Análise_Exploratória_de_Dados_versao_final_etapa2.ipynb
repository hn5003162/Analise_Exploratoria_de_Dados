# %% [markdown]
# <a href="https://colab.research.google.com/github/hn5003162/Analise_Exploratoria_de_Dados/blob/main/Projeto_Aplicado_I_An%C3%A1lise_Explorat%C3%B3ria_de_Dados_versao_final_etapa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploração inicial dos dados:

# %%
import pandas as pd
# Leitura do dataframe. O parâmetro decimal = "," informa que a "," deve ser considerado como separador de decimais. sep = "|" indica qual é o separados dos campos.
base = pd.read_csv("https://raw.githubusercontent.com/hn5003162/Mack_Projeto_Aplicado_I/main/base-projeto-aplicado-i.csv",sep="|",decimal = ",")

# Exploração inicial dos dados. Primeiros registros:
base.head()
# Out:
#     ano sigla_uf   nome_uf nome_regiao produto  area_plantada  area_colhida  \
# 0  2010       AC      Acre       Norte    Café         1271.0        1003.0
# 1  2010       AL   Alagoas    Nordeste    Café            5.0           5.0
# 2  2010       AM  Amazonas       Norte    Café         2432.0        2048.0
# 3  2010       AP     Amapá       Norte    Café            NaN           NaN
# 4  2010       BA     Bahia    Nordeste    Café       152056.0      152056.0
#
#    quantidade_produzida   perdas  valor_producao  ...  area_cafe  \
# 0                1029.0  279.847          2777.0  ...        NaN
# 1                   2.0    0.000             1.0  ...        NaN
# 2                3902.0  758.988          8804.0  ...        NaN
# 3                   NaN      NaN             NaN  ...        NaN
# 4              153262.0    0.000        560050.0  ...        NaN
#
#    producao_cafe  valor_total_producao_cafe  despesa_total_comparacao  \
# 0            NaN                        NaN                       NaN
# 1            NaN                        NaN                       NaN
# 2            NaN                        NaN                       NaN
# 3            NaN                        NaN                       NaN
# 4            NaN                        NaN                       NaN
#
#    despesa_total  despesa_defensivos  quantidade_tratores  \
# 0            NaN                 NaN                  NaN
# 1            NaN                 NaN                  NaN
# 2            NaN                 NaN                  NaN
# 3            NaN                 NaN                  NaN
# 4            NaN                 NaN                  NaN
#
#    quantidade_maquina_colheita  quantidade_maquinas_plantio  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    proporcao_despesa_defensivos
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 23 columns]

# %%
# Dados sobre o dataset: número de linhas e de colunas
base.shape
# Out:
# (216, 23)

# %%
# Estrutura do dataset
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ano                               216 non-null    int64
#  1   sigla_uf                          216 non-null    object
#  2   nome_uf                           216 non-null    object
#  3   nome_regiao                       216 non-null    object
#  4   produto                           216 non-null    object
#  5   area_plantada                     129 non-null    float64
#  6   area_colhida                      129 non-null    float64
#  7   quantidade_produzida              129 non-null    float64
#  8   perdas                            129 non-null    float64
#  9   valor_producao                    129 non-null    float64
#  10  emissao                           216 non-null    float64
#  11  area_nao_utilizada                27 non-null     float64
#  12  quantidade_estabelecimentos_cafe  27 non-null     float64
#  13  area_cafe                         27 non-null     float64
#  14  producao_cafe                     27 non-null     float64
#  15  valor_total_producao_cafe         27 non-null     float64
#  16  despesa_total_comparacao          27 non-null     float64
#  17  despesa_total                     27 non-null     float64
#  18  despesa_defensivos                27 non-null     float64
#  19  quantidade_tratores               27 non-null     float64
#  20  quantidade_maquina_colheita       27 non-null     float64
#  21  quantidade_maquinas_plantio       27 non-null     float64
#  22  proporcao_despesa_defensivos      27 non-null     float64
# dtypes: float64(18), int64(1), object(4)
# memory usage: 38.9+ KB

# %%
# Valores das colunas
base.describe(include='all')
# Out:
#                ano sigla_uf nome_uf nome_regiao produto  area_plantada  \
# count    216.00000      216     216         216     216   1.290000e+02
# unique         NaN       27      27           5       1            NaN
# top            NaN       AC    Acre    Nordeste    Café            NaN
# freq           NaN        8       8          72     216            NaN
# mean    2013.50000      NaN     NaN         NaN     NaN   1.265915e+05
# std        2.29661      NaN     NaN         NaN     NaN   2.563047e+05
# min     2010.00000      NaN     NaN         NaN     NaN   5.000000e+00
# 25%     2011.75000      NaN     NaN         NaN     NaN   1.648000e+03
# 50%     2013.50000      NaN     NaN         NaN     NaN   1.120100e+04
# 75%     2015.25000      NaN     NaN         NaN     NaN   1.520560e+05
# max     2017.00000      NaN     NaN         NaN     NaN   1.041541e+06
#
#         area_colhida  quantidade_produzida       perdas  valor_producao  ...  \
# count   1.290000e+02          1.290000e+02   129.000000    1.290000e+02  ...
# unique           NaN                   NaN          NaN             NaN  ...
# top              NaN                   NaN          NaN             NaN  ...
# freq             NaN                   NaN          NaN             NaN  ...
# mean    1.262692e+05          1.765149e+05   328.541264    9.987940e+05  ...
# std     2.561992e+05          3.834141e+05  1159.013713    2.433704e+06  ...
# min     5.000000e+00          2.000000e+00     0.000000    1.000000e+00  ...
# 25%     1.538000e+03          1.534000e+03     0.000000    6.687000e+03  ...
# 50%     1.120100e+04          1.218200e+04     0.399000    4.017100e+04  ...
# 75%     1.520560e+05          1.408360e+05    81.667000    6.946090e+05  ...
# max     1.041540e+06          1.834171e+06  7307.301000    1.402012e+07  ...
#
#             area_cafe  producao_cafe  valor_total_producao_cafe  \
# count       27.000000   2.700000e+01               2.700000e+01
# unique            NaN            NaN                        NaN
# top               NaN            NaN                        NaN
# freq              NaN            NaN                        NaN
# mean     46251.148148   6.761174e+04               5.320704e+05
# std     174508.631602   2.661681e+05               1.968547e+06
# min          0.000000   0.000000e+00               0.000000e+00
# 25%          0.000000   0.000000e+00               2.835000e+03
# 50%        144.000000   6.500000e+01               1.702600e+04
# 75%       2758.500000   3.766000e+03               1.520090e+05
# max     903032.000000   1.380573e+06               1.024950e+07
#
#         despesa_total_comparacao  despesa_total  despesa_defensivos  \
# count               2.700000e+01   2.700000e+01           27.000000
# unique                       NaN            NaN                 NaN
# top                          NaN            NaN                 NaN
# freq                         NaN            NaN                 NaN
# mean                1.190120e+06   1.701248e+06       151573.481481
# std                 1.750389e+06   2.354958e+06       155577.287171
# min                 4.971000e+03   5.438300e+04         3206.000000
# 25%                 4.696500e+04   4.743115e+05        50729.500000
# 50%                 2.878030e+05   6.798150e+05       100601.000000
# 75%                 1.990214e+06   2.140766e+06       200419.000000
# max                 6.268032e+06   1.097884e+07       673111.000000
#
#         quantidade_tratores  quantidade_maquina_colheita  \
# count          2.700000e+01                 2.700000e+01
# unique                  NaN                          NaN
# top                     NaN                          NaN
# freq                    NaN                          NaN
# mean           1.702416e+07                 5.828436e+06
# std            2.089218e+07                 6.276819e+06
# min            3.527460e+05                 9.003300e+04
# 25%            2.371060e+06                 1.164270e+06
# 50%            6.544964e+06                 2.830683e+06
# 75%            2.395181e+07                 9.269072e+06
# max            5.971232e+07                 2.344271e+07
#
#         quantidade_maquinas_plantio  proporcao_despesa_defensivos
# count                  2.700000e+01                     27.000000
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                   4.075691e+06                      0.136222
# std                    4.672099e+06                      0.084676
# min                    6.421900e+04                      0.036000
# 25%                    6.891330e+05                      0.065000
# 50%                    1.296181e+06                      0.109000
# 75%                    6.730812e+06                      0.191500
# max                    1.824127e+07                      0.312000
#
# [11 rows x 23 columns]

# %% [markdown]
# Análise dos dados para respoder a algumas perguntas: (H)
#
# Qual é a relação entre a área plantada e a emissão de gases de efeito estufa?
#
# Qual é a relação entre a quantidade produzida e a emissão de gases de efeito estufa?
#
# Qual é a relação entre a produtividade (quantidade_produzida / area_plantada) e a emissão de gases de efeito estufa?

# %%
# Cria o dataframe e retira todo e qualquer registro com NaN, seja da area plantada, da quantidade produzida ou na emissao"
base_emissao_por_area_ou_qtd = base[["nome_regiao","area_plantada","quantidade_produzida","emissao"]]
base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.dropna()

# Agrupa os dados por região e soma as áreas plantadas, quantidades produzidas e as emissões
base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.groupby(["nome_regiao"])
base_emissao_por_area_ou_qtd = base_emissao_por_area_ou_qtd.sum()

# adiciona uma coluna da produtividade (quantidade_produzida / area_plantada)
base_emissao_por_area_ou_qtd["produtividade"] = base_emissao_por_area_ou_qtd["quantidade_produzida"] / base_emissao_por_area_ou_qtd["area_plantada"]

# adiciona uma coluna com a relação entre as emissões e a área plantada.
base_emissao_por_area_ou_qtd["emissao_por_area_plantada"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["area_plantada"]
# adiciona uma coluna com a relação entre as emissões e a quantidade produzida
base_emissao_por_area_ou_qtd["emissao_por_qtd_produzida"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["quantidade_produzida"]

# adiciona uma coluna com a relação entre as emissões e a produtividade
base_emissao_por_area_ou_qtd["emissao_por_produtividade"] = base_emissao_por_area_ou_qtd["emissao"] / base_emissao_por_area_ou_qtd["produtividade"]


display(base_emissao_por_area_ou_qtd)
# Out:
#               area_plantada  quantidade_produzida      emissao  produtividade  \
# nome_regiao
# Centro-oeste       221474.0              229522.0  1767311.367       1.036338
# Nordeste          1318472.0             1334635.0  1250093.182       1.012259
# Norte              924910.0              857190.0    16515.290       0.926782
# Sudeste          13403920.0            19647970.0   883600.881       1.465838
# Sul                461527.0              701108.0  1375359.190       1.519105
#
#               emissao_por_area_plantada  emissao_por_qtd_produzida  \
# nome_regiao
# Centro-oeste                   7.979769                   7.699965
# Nordeste                       0.948138                   0.936655
# Norte                          0.017856                   0.019267
# Sudeste                        0.065921                   0.044972
# Sul                            2.980019                   1.961694
#
#               emissao_por_produtividade
# nome_regiao
# Centro-oeste               1.705342e+06
# Nordeste                   1.234954e+06
# Norte                      1.782004e+04
# Sudeste                    6.027959e+05
# Sul                        9.053746e+05

# %% [markdown]
# Quais sãs as perda de cada região? (H)

# %%
# TO DO: procurar ouliers e remover da análise

# Cria um dataframe, eliminando registro que contenha NaN em perdas ou area plantada
base_perda_por_regiao = base[["nome_regiao","perdas","area_plantada"]]
base_perda_por_regiao.dropna()

# Agrupa os dados por ano e região e soma as perdas e areas plantadas
base_perda_por_regiao = base_perda_por_regiao.groupby(['nome_regiao'])
base_perda_por_regiao = base_perda_por_regiao.sum()

# Calculas as perdar por cada região divindo as perdas pela área plantada
base_perda_por_regiao["perda_por_area_plantada"] = base_perda_por_regiao["perdas"] / base_perda_por_regiao["area_plantada"]

# Exibe o dataframe como uma tabela
display(base_perda_por_regiao)
# Out:
#                  perdas  area_plantada  perda_por_area_plantada
# nome_regiao
# Centro-oeste    582.188       221474.0                 0.002629
# Nordeste      11285.072      1318472.0                 0.008559
# Norte         14665.339       924910.0                 0.015856
# Sudeste       12620.574     13403920.0                 0.000942
# Sul            3228.650       461527.0                 0.006996

# %% [markdown]
# 4) Qual a relação do desperdício com a emissão de gases do efeito estufa?

# %%
# Agrupando por ano e região e somando as áreas plantadas, áreas colhidas e emissões
base_emissao = base[["ano", "nome_regiao", "area_plantada", "area_colhida", "emissao"]]
base_emissao = base_emissao.dropna()

base_emissao = base_emissao.groupby(['ano', 'nome_regiao']).sum()

base_emissao['perda'] = base_emissao["area_plantada"].sub(base_emissao["area_colhida"])

# Calculando a relação entre a perda e a emissao de gases de efeito estufa
base_emissao['relacao_perda_emissao'] = base_emissao['perda'] / base_emissao['emissao']
display(base_emissao)
# Out:
#                    area_plantada  area_colhida     emissao   perda  \
# ano  nome_regiao
# 2010 Centro-oeste        27465.0       27400.0  190981.313    65.0
#      Nordeste           163366.0      163366.0  153126.450     0.0
#      Norte              171510.0      170858.0    1529.542   652.0
#      Sudeste           1716810.0     1715488.0   94255.340  1322.0
#      Sul                 82673.0       82673.0  180369.194     0.0
# 2011 Centro-oeste        30841.0       30841.0  237783.155     0.0
#      Nordeste           166370.0      166370.0  173521.083     0.0
#      Norte              167140.0      166916.0    1777.512   224.0
#      Sudeste           1709794.0     1709794.0  101137.576     0.0
#      Sul                 74854.0       74854.0  165273.588     0.0
# 2012 Centro-oeste        31517.0       31517.0  245794.916     0.0
#      Nordeste           169260.0      168884.0  158757.466   376.0
#      Norte              138064.0      137554.0    2093.929   510.0
#      Sudeste           1711332.0     1710549.0  103940.732   783.0
#      Sul                 72400.0       71576.0  160455.400   824.0
# 2013 Centro-oeste        28790.0       28770.0  209243.539    20.0
#      Nordeste           170690.0      170628.0  148660.520    62.0
#      Norte              107926.0      100043.0    2445.375  7883.0
#      Sudeste           1721887.0     1721222.0  106242.297   665.0
#      Sul                 64964.0       64859.0  156090.551   105.0
# 2014 Centro-oeste        27386.0       27386.0  228969.004     0.0
#      Nordeste           170957.0      169829.0  158949.291  1128.0
#      Norte               92310.0       92009.0    2546.435   301.0
#      Sudeste           1673165.0     1672778.0  112129.905   387.0
#      Sul                 38333.0       35825.0  187367.119  2508.0
# 2015 Centro-oeste        28812.0       28651.0  219638.838   161.0
#      Nordeste           173955.0      170524.0  160088.009  3431.0
#      Norte               84056.0       83791.0    2095.854   265.0
#      Sudeste           1654702.0     1650197.0  119766.073  4505.0
#      Sul                 44747.0       44551.0  179059.917   196.0
# 2016 Centro-oeste        24259.0       24179.0  207676.099    80.0
#      Nordeste           172040.0      170236.0  149338.100  1804.0
#      Norte               89774.0       81631.0    2308.124  8143.0
#      Sudeste           1679099.0     1677232.0  122167.574  1867.0
#      Sul                 43388.0       43326.0  181308.248    62.0
# 2017 Centro-oeste        22404.0       22401.0  227224.503     3.0
#      Nordeste           131834.0      128935.0  147652.263  2899.0
#      Norte               74130.0       73971.0    1718.519   159.0
#      Sudeste           1537131.0     1536983.0  123961.384   148.0
#      Sul                 40168.0       40127.0  165435.173    41.0
#
#                    relacao_perda_emissao
# ano  nome_regiao
# 2010 Centro-oeste               0.000340
#      Nordeste                   0.000000
#      Norte                      0.426271
#      Sudeste                    0.014026
#      Sul                        0.000000
# 2011 Centro-oeste               0.000000
#      Nordeste                   0.000000
#      Norte                      0.126019
#      Sudeste                    0.000000
#      Sul                        0.000000
# 2012 Centro-oeste               0.000000
#      Nordeste                   0.002368
#      Norte                      0.243561
#      Sudeste                    0.007533
#      Sul                        0.005135
# 2013 Centro-oeste               0.000096
#      Nordeste                   0.000417
#      Norte                      3.223636
#      Sudeste                    0.006259
#      Sul                        0.000673
# 2014 Centro-oeste               0.000000
#      Nordeste                   0.007097
#      Norte                      0.118204
#      Sudeste                    0.003451
#      Sul                        0.013385
# 2015 Centro-oeste               0.000733
#      Nordeste                   0.021432
#      Norte                      0.126440
#      Sudeste                    0.037615
#      Sul                        0.001095
# 2016 Centro-oeste               0.000385
#      Nordeste                   0.012080
#      Norte                      3.527973
#      Sudeste                    0.015282
#      Sul                        0.000342
# 2017 Centro-oeste               0.000013
#      Nordeste                   0.019634
#      Norte                      0.092522
#      Sudeste                    0.001194
#      Sul                        0.000248

# %% [markdown]
# Diminuir a perda reflete diretamente na diminuição da emissão dos gases?

# %%
# Correlacionando a perda e a emissão de gases de efeito estufa
correlacao = base_emissao['perda'].corr(base_emissao['emissao'])

# Correlação negativa: significa que há uma relação inversa entre perda e emissão.
# Correlação positiva: significa que há uma relação direta entre perda e emissão.

print(f"A correlação entre a perda e emissão de gases de efeito estufa é: {correlacao}")
# Out:
# A correlação entre a perda e emissão de gases de efeito estufa é: -0.37188874721613097

# %% [markdown]
# Qual a relação entre a produtividade e a emissão de gases do efeito estufa?

# %%
# Calculo da produtividade
base['produtividade'] = base['producao_cafe'] / base['area_colhida']
# Agrupamento por ano e região e calculo da média da produtividade e a soma das emissões
base_prod_emissao = base.groupby(['ano', 'nome_regiao'])[['produtividade', 'emissao']].agg({'produtividade':'mean', 'emissao':'sum'})
# Relação entre a produtividade e emissão de gases de efeito estufa
base_prod_emissao['relacao_prod_emissao'] = base_prod_emissao['produtividade'] / base_prod_emissao['emissao']
display(base_prod_emissao)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6bdf78709ce2> in <cell line: 2>()
#       1 # Calculo da produtividade
# ----> 2 base['produtividade'] = base['producao_cafe'] / base['area_colhida']
#       3 # Agrupamento por ano e região e calculo da média da produtividade e a soma das emissões
#       4 base_prod_emissao = base.groupby(['ano', 'nome_regiao'])[['produtividade', 'emissao']].agg({'produtividade':'mean', 'emissao':'sum'})
#       5 # Relação entre a produtividade e emissão de gases de efeito estufa
#
# NameError: name 'base' is not defined

# %% [markdown]
# Qual a relaçção entre a produtividade e a perda considerando os 5 estados com maior produtividade? (NC)

# %%
# Calculo da produtividade
base['produtividade'] = base['producao_cafe'] / base['area_colhida']
# Agrupamento por estado e calculo da média da produtividade e a soma das perdas
base_prod_perda = base.groupby(['nome_uf'])[['produtividade', 'perdas']].agg({'produtividade':'mean', 'perdas':'sum'})
# Ordenamento dos estados pela produtividade em ordem decrescente e selecionando os 5 primeiros
top_5_estados = base_prod_perda.nlargest(5, 'produtividade')
# Relação entre produtividade e perda
top_5_estados['relacao_prod_perda'] = top_5_estados['produtividade'] / top_5_estados['perdas']
display(top_5_estados)
# Out:
#                   produtividade    perdas  relacao_prod_perda
# nome_uf
# Paraná                 1.512573  3228.650            0.000468
# Minas Gerais           1.492337  7608.475            0.000196
# Distrito Federal       1.382576   382.617            0.003613
# Goiás                  1.180804   171.693            0.006877
# São Paulo              1.033400  2913.782            0.000355

# %% [markdown]
# Gráfico 1

# %%
import matplotlib.pyplot as plt

# Ordene o DataFrame pelas perdas em ordem decrescente

base_perda_por_regiao_sorted = base_perda_por_regiao.sort_values(by='perdas', ascending=False)

# Crie uma figura

plt.figure(figsize=(12, 6))

# Crie barras para perdas

plt.bar(base_perda_por_regiao_sorted.index, base_perda_por_regiao_sorted["perdas"], label="Perdas", alpha=0.7)

# Configure o título e os rótulos dos eixos

plt.title("Perdas por Região (do Maior para o Menor)")

plt.xlabel("Região")

plt.ylabel("Perdas")

# Gire os rótulos do eixo x para melhor legibilidade

plt.xticks(rotation=45)

# Exiba o gráfico

plt.tight_layout()

plt.show()

# %%
Gráfico 2

# %%
import matplotlib.pyplot as plt

import numpy as np

base_perda_por_regiao_sorted = base_perda_por_regiao.sort_values(by='perdas', ascending=False)

# Crie uma figura com dois subplots

fig,i(ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Gráfico 1: Perdas

ax1.bar(base_perda_por_regiao_sorted.index, base_perda_por_regiao_sorted["perdas"], label="Perdas", alpha=0.7)

ax1.set_title("Perdas por Região (do Maior para o Menor)")

ax1.set_xlabel("Região")

ax1.set_ylabel("Perdas")

# Gire os rótulos do eixo x para melhor legibilidade

ax1.set_xticklabels(base_perda_por_regiao_sorted.index, rotation=45)

# Gráfico 2: Perda por Área Plantada

factor = 5000 # Fator de escala para perda por área plantada

ax2.bar(

base_perda_por_regiao_sorted.index,

base_perda_por_regiao_sorted["perda_por_area_plantada"] * factor,

label="Perda por Área Plantada (escala)",

alpha=0.7,

)

ax2.set_title("Perda por Área Plantada por Região (do Maior para o Menor)")

ax2.set_xlabel("Região")

ax2.set_ylabel("Perda por Área Plantada (escala)")

# Gire os rótulos do eixo x para melhor legibilidade

ax2.set_xticklabels(base_perda_por_regiao_sorted.index, rotation=45)

# Exiba o gráfico

plt.tight_layout()

plt.show()
# Out:
#   File "<ipython-input-13-8510644a8f19>", line 9
#     fig,i(ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
#         ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
